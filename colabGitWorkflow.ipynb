# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Class-20210420-01/GilangLazuardi_Day23'
# Out:
# /content/drive/.shortcut-targets-by-id/1Atr52kQtpKI__DG99japz14wr8jXJe6S/Class-20210420-01/GilangLazuardi_Day23

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1Atr52kQtpKI__DG99japz14wr8jXJe6S/Class-20210420-01/GilangLazuardi_Day23

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/.shortcut-targets-by-id/1Atr52kQtpKI__DG99japz14wr8jXJe6S/Class-20210420-01/GilangLazuardi_Day23/.git/

# %%
git remote rm origin
# !git remote add origin https://gilanglazu:Lazuardi1617@github.com/gilanglazu/student-grade-prediction.git
# !git remote -v
# Out:
#   File "<ipython-input-21-32cd4fc5a727>", line 1
#     git remote rm origin
#              ^
# SyntaxError: invalid syntax

# %%
# !git config --global user.email 'gilanglazu@gmail.com'
# !git config --global user.name 'gilang'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master c1bb776] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://gilanglazu:lazuardi1617@github.com/gilanglazu/student-grade-prediction.git/'
